# %% [markdown]
# # Physics 482 Homework Set 9

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# ### Problem 3

# %%
## Part 3 ##
tetoT = np.linspace(0,np.pi, 100)
tetoI = np.linspace(0,np.pi, 100)
a = 2*np.sqrt(1 - (np.sin(tetoI)/2)**2)/np.cos(tetoI) #n2/n1*(u1/u2), n2/n1 = 2 and u1=u2=1

transmissionimpossible = (2/(a+1))
reflexonthehaters = (1-a)/(a+1)

plt.plot(tetoI, transmissionimpossible)
plt.plot(tetoI, reflexonthehaters)
#plt.plot(tetoI,a,'.')

# %%
1 - (2*np.sin(1.5))**2
# Out:
# -2.979984993200891
